# %% [markdown]
# # Logistic Regression
#
# #### Difference b/w Linear and Logistic regression

# %% [markdown]
# <img src="images/difference.png" width="900" height="200">

# %% [markdown]
# ## Logistic Regression Steps:

# %% [markdown]
# <img src="images/Logistic_regression.png" width="900" height="400">
