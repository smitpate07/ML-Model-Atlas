# %% [markdown]
# # Linear Regression
#
# <img src="images/Linear_regression.png" width="500" height="400">

# %% [markdown]
# #### What is Linear Regression ?

# %% [markdown]
# - Model in which addition or subtraction of parameters is performed is a linear model. Model that uses multiplication or power is a non-linear model.

# %% [markdown]
# #### Linear Regression Steps:

# %% [markdown]
# <img src="images/Linear_regression_steps.png" width="900" height="400">
